# %%
# %run steel.ipynb

# %%
steel_exec()
# Out:
# Epoch1: loss=15.888, accuracy=0.310/0.379
# Epoch2: loss=16.118, accuracy=0.300/0.284
# Epoch3: loss=16.579, accuracy=0.280/0.286
# Epoch4: loss=18.421, accuracy=0.200/0.361
# Epoch5: loss=19.111, accuracy=0.170/0.197
# Epoch6: loss=17.500, accuracy=0.240/0.130
# Epoch7: loss=16.118, accuracy=0.300/0.455
# Epoch8: loss=15.888, accuracy=0.310/0.238
# Epoch9: loss=16.809, accuracy=0.270/0.223
# Epoch10: loss=17.269, accuracy=0.250/0.197
#
# Final Test: final accuracy = 0.197

# %%
LEARNING_RATE = 0.0001
steel_exec()
# Out:
# Epoch1: loss=17.447, accuracy=0.230/0.217
# Epoch2: loss=17.500, accuracy=0.240/0.343
# Epoch3: loss=17.730, accuracy=0.230/0.368
# Epoch4: loss=15.197, accuracy=0.340/0.182
# Epoch5: loss=16.579, accuracy=0.280/0.407
# Epoch6: loss=15.427, accuracy=0.330/0.450
# Epoch7: loss=16.809, accuracy=0.270/0.394
# Epoch8: loss=15.658, accuracy=0.320/0.335
# Epoch9: loss=17.039, accuracy=0.260/0.425
# Epoch10: loss=16.809, accuracy=0.270/0.279
#
# Final Test: final accuracy = 0.279

# %%
print(weight)
# Out:
# [[ 1.45614180e-01 -1.88363681e-01 -9.14325044e-01  7.27611189e-02
#    8.15885302e-04  4.54638825e-01  4.25494550e-01]
#  [ 1.31768595e-01 -1.91516335e-01 -8.42358255e-01  7.42978369e-02
#   -1.87939206e-02  4.23770535e-01  4.17120056e-01]
#  [-6.61983679e+01 -5.56721184e+00  1.35231732e+01 -8.28705884e+01
#    3.54966675e+01  1.52420522e+02 -4.68111735e+01]
#  [-6.61920171e+01 -5.54724438e+00  1.35143080e+01 -8.28756626e+01
#    3.55034185e+01  1.52388136e+02 -4.67876840e+01]
#  [-4.95529364e-01 -1.33857475e-01  3.77146392e+00 -1.11538267e-01
#   -4.49685759e-01 -1.49119020e+00 -1.08202492e+00]
#  [-3.50554957e-02  1.09192670e-02  1.46549900e-01 -1.11131597e-02
#   -2.26491777e-02 -7.48611986e-02 -2.03067431e-02]
#  [-6.99235840e-03  1.51909241e-02  5.44395846e-02 -7.61676549e-03
#   -1.10923784e-03 -5.52054813e-02  4.40644403e-03]
#  [-5.38767230e+01 -1.92592215e+01  4.09056374e+02 -1.16648443e+01
#   -4.81752547e+01 -1.52401148e+02 -1.23666322e+02]
# ...

# %%
print(bias)
# Out:
# [-9.97063846e-05  2.70000000e-04 -7.70000000e-04  8.97063846e-05
#  -8.00000000e-05  7.00000000e-05  5.20000000e-04]

# %%
#print(entropy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c6405c63e17f> in <module>
# ----> 1 print(entropy)
#
# NameError: name 'entropy' is not defined
